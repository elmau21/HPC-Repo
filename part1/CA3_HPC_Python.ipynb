# %%
"""Julia set generator with PIL-based image drawing"""
import time
from PIL import Image
import array

# area of complex space to investigate
x1, x2, y1, y2 = -1.8, 1.8, -1.8, 1.8
c_real, c_imag = -0.62772, -.42193


def show_greyscale(output_raw, width, height, max_iterations):
    """Convert list to array, show using PIL"""
    # convert our output to PIL-compatible input
    # scale to [0...255]
    max_iterations = float(max(output_raw))
    print(max_iterations)
    scale_factor = float(max_iterations)
    scaled = [int(o / scale_factor * 255) for o in output_raw]
    output = array.array('B', scaled)  # array of unsigned ints
    # display with PIL
    im = Image.new("L", (width, width))
    # EXPLAIN RAW L 0 -1
    im.frombytes(output.tobytes(), "raw", "L", 0, -1)
    im.save('julia_greyscale.png')


def show_false_greyscale(output_raw, width, height, max_iterations):
    """Convert list to array, show using PIL"""
    # convert our output to PIL-compatible input
    assert width * height == len(output_raw)  # sanity check our 1D array and desired 2D form
    # rescale output_raw to be in the inclusive range [0..255]
    max_value = float(max(output_raw))
    output_raw_limited = [int(float(o) / max_value * 255) for o in output_raw]
    # create a slightly fancy colour map that shows colour changes with
    # increased contrast (thanks to John Montgomery)
    output_rgb = ((o + (256 * o) + (256 ** 2) * o) * 16 for o in output_raw_limited)  # fancier
    output_rgb = array.array('I', output_rgb)  # array of unsigned ints (size is platform specific)
    # display with PIL/pillow
    im = Image.new("RGB", (width, height))
    # EXPLAIN RGBX L 0 -1
    im.frombytes(output_rgb.tobytes(), "raw", "RGBX", 0, -1)
    im.save('julia_falseGreyscale.png')


def calculate_z_serial_purepython(maxiter, zs, cs):
    """Calculate output list using Julia update rule"""
    output = [0] * len(zs)
    for i in range(len(zs)):
        n = 0
        z = zs[i]
        c = cs[i]
        while abs(z) < 2 and n < maxiter:
            z = z * z + c
            n += 1
        output[i] = n
    return output


def calc_pure_python(draw_output, desired_width, max_iterations):
    """Create a list of complex co-ordinates (zs) and complex parameters (cs), build Julia set and display"""
    x_step = (x2 - x1) / desired_width
    y_step = (y1 - y2) / desired_width
    x = []
    y = []
    ycoord = y2
    while ycoord > y1:
        y.append(ycoord)
        ycoord += y_step
    xcoord = x1
    while xcoord < x2:
        x.append(xcoord)
        xcoord += x_step
    # set width and height to the generated pixel counts, rather than the
    # pre-rounding desired width and height
    width = len(x)
    height = len(y)
    # build a list of co-ordinates and the initial condition for each cell.
    # Note that our initial condition is a constant and could easily be removed,
    # we use it to simulate a real-world scenario with several inputs to our function
    zs = []
    cs = []
    for ycoord in y:
        for xcoord in x:
            zs.append(complex(xcoord, ycoord))
            cs.append(complex(c_real, c_imag))

    print("Length of x:", len(x))
    print("Total elements:", len(zs))
    start_time = time.time()
    output = calculate_z_serial_purepython(max_iterations, zs, cs)
    end_time = time.time()
    secs = end_time - start_time
    print(calculate_z_serial_purepython.__name__ + " took", secs, "seconds")

    assert sum(output) == 33219980  # this sum is expected for 1000^2 grid with 300 iterations

    if draw_output:
        show_false_greyscale(output, width, height, max_iterations)
        show_greyscale(output, width, height, max_iterations)


if __name__ == "__main__":
    # Calculate the Julia set using a pure Python solution with
    # reasonable defaults for a laptop
    # set draw_output to True to use PIL to draw an image
    calc_pure_python(draw_output=True, desired_width=1000, max_iterations=300)
# Out:
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.59992527961731 seconds
# 300.0

# %%
"""Julia set generator without PIL-based image drawing"""
import time

# area of complex space to investigate
x1, x2, y1, y2 = -1.8, 1.8, -1.8, 1.8
c_real, c_imag = -0.62772, -.42193


def calculate_z_serial_purepython(maxiter, zs, cs):
    """Calculate output list using Julia update rule"""
    output = [0] * len(zs)
    for i in range(len(zs)):
        n = 0
        z = zs[i]
        c = cs[i]
        while abs(z) < 2 and n < maxiter:
            z = z * z + c
            n += 1
        output[i] = n
    return output


def calc_pure_python(desired_width, max_iterations):
    """Create a list of complex co-ordinates (zs) and complex parameters (cs), build Julia set and display"""
    x_step = (x2 - x1) / desired_width
    y_step = (y1 - y2) / desired_width
    x = []
    y = []
    ycoord = y2
    while ycoord > y1:
        y.append(ycoord)
        ycoord += y_step
    xcoord = x1
    while xcoord < x2:
        x.append(xcoord)
        xcoord += x_step
    # build a list of co-ordinates and the initial condition for each cell.
    # Note that our initial condition is a constant and could easily be removed,
    # we use it to simulate a real-world scenario with several inputs to our function
    zs = []
    cs = []
    for ycoord in y:
        for xcoord in x:
            zs.append(complex(xcoord, ycoord))
            cs.append(complex(c_real, c_imag))

    print("Length of x:", len(x))
    print("Total elements:", len(zs))
    start_time = time.time()
    output = calculate_z_serial_purepython(max_iterations, zs, cs)
    end_time = time.time()
    secs = end_time - start_time
    print(calculate_z_serial_purepython.__name__ + " took", secs, "seconds")

    assert sum(output) == 33219980  # this sum is expected for 1000^2 grid with 300 iterations


if __name__ == "__main__":
    # Calculate the Julia set using a pure Python solution with
    # reasonable defaults for a laptop
    # set draw_output to True to use PIL to draw an image
    calc_pure_python(desired_width=1000, max_iterations=300)
# Out:
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.425326108932495 seconds

# %%
# Run 10 loops with 5 repetitions

#notebook
# %timeit -n 10 -r 5 calc_pure_python(desired_width=1000, max_iterations=300)
# Out:
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.801400184631348 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.477102994918823 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.762004375457764 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.345909357070923 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.8440985679626465 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.659919738769531 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.471553564071655 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.396697521209717 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.380038738250732 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.734334707260132 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.3841400146484375 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 7.291157960891724 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.696113109588623 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.52416729927063 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 7.232149362564087 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.266458511352539 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.2760162353515625 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.864908933639526 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.443450927734375 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.616187334060669 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 7.072129487991333 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.297415733337402 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.506796836853027 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 7.121746301651001 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 7.133193254470825 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.731460809707642 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.691608190536499 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.486429214477539 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.499738931655884 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.487216234207153 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.5611536502838135 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.473454475402832 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.496905088424683 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.42069935798645 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.583277940750122 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.568626403808594 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.558870553970337 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.622986078262329 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.5313591957092285 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.601855516433716 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.843851327896118 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.448499441146851 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.553126811981201 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.669578790664673 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.526501655578613 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.587003469467163 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.464494705200195 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.552032709121704 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.561320066452026 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.609191179275513 seconds
# 6.96 s ± 58.4 ms per loop (mean ± std. dev. of 5 runs, 10 loops each)

# %%
#Use the cProfile module to profilethe source code 

# terminal
#python -m cProfile -s cumulative part1.py
#python -m cProfile -o profile.stats part1.py

# notebook
import pstats

p = pstats.Stats("profile.stats")
p.sort_stats("cumulative")

p.print_stats()

p.print_callers()

p.print_callees()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 10
#       1 #Use the cProfile module to profilethe source code
#       2
#       3 # terminal
#    (...)
#       6
#       7 # notebook
#       8 import pstats
# ---> 10 p = pstats.Stats("profile.stats")
#      11 p.sort_stats("cumulative")
#      13 p.print_stats()
#
# File D:\Python\lib\pstats.py:114, in Stats.__init__(self, stream, *args)
#     112     arg = args[0]
#     113     args = args[1:]
# --> 114 self.init(arg)
#     115 self.add(*args)
#
# File D:\Python\lib\pstats.py:128, in Stats.init(self, arg)
#     126 self.stats = {}
#     127 self.sort_arg_dict = {}
# --> 128 self.load_stats(arg)
#     129 try:
#     130     self.get_top_level_stats()
#
# File D:\Python\lib\pstats.py:141, in Stats.load_stats(self, arg)
#     139     return
#     140 elif isinstance(arg, str):
# --> 141     with open(arg, 'rb') as f:
#     142         self.stats = marshal.load(f)
#     143     try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'profile.stats'

# %%
#Use snakeviz to get a high-level understanding of thecPrifile statistics file

# terminal
#snakeviz profile.stats

# notebook
# %load_ext snakeviz
# %snakeviz calc_pure_python(desired_width=1000, max_iterations=300)
# Out:
# The snakeviz extension is already loaded. To reload it, use:
#   %reload_ext snakeviz
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.681885004043579 seconds
#
# *** Profile stats marshalled to file '/tmp/tmp50dsjdkc'.
# Embedding SnakeViz in this document...
# <function display at 0x7eb9a95680d0>
# <iframe id='snakeviz-9898a71a-e811-11ee-8d17-0131fda8c8ea' frameborder=0 seamless width='100%' height='1000'></iframe>
# <script>document.getElementById("snakeviz-9898a71a-e811-11ee-8d17-0131fda8c8ea").setAttribute("src", "http://" + document.location.hostname + ":8081/snakeviz/%2Ftmp%2Ftmp50dsjdkc")</script>

# %%
# Use the line_profiler and kernprof file to profile line-by-line the function calculate_z_serial_purepython.

# run in terminal the following commands
#kernprof -l -v part1_lineprofiler.py
#kernprof -l -v part1_lineprofiler2.py

# %%
# Use the memory_profiler to diagnose memory usage

# run in terminal the following commands
#python3 -m memory_profiler part1_memoryprofiler.py
